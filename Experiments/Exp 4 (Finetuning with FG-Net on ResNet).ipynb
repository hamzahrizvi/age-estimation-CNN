# %%
from tensorflow import keras

new_model = keras.Sequential(k_means_wiki.layers[:-2])

# %%
new_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  dense_3 (Dense)             (None, 4000)              100356000
#
#  dropout_1 (Dropout)         (None, 4000)              0
#
# =================================================================
# Total params: 115,070,688
# Trainable params: 0
# Non-trainable params: 115,070,688
# _________________________________________________________________

# %%
# new_model.trainable = False ## Not trainable weights
dense_layer_1 = layers.Dense(2000, activation='relu')
dropout = layers.Dropout(0.5)
dense_layer_2 = layers.Dense(200, activation='relu')
prediction_layer = layers.Dense(18, activation='softmax')


fgnet_model = models.Sequential([
    new_model,
    dense_layer_1,
    dropout,
    dense_layer_2,
    dropout,
    prediction_layer
])
fgnet_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 4000)              115070688
#
#  dense_2 (Dense)             (None, 2000)              8002000
#
#  dropout_1 (Dropout)         multiple                  0
#
#  dense_3 (Dense)             (None, 200)               400200
#
#  dense_4 (Dense)             (None, 18)                3618
#
# =================================================================
# Total params: 123,476,506
# Trainable params: 8,405,818
# Non-trainable params: 115,070,688
# _________________________________________________________________

# %%
# fgnet data generator for vgg16 model pretrained on 

from keras_preprocessing.image import ImageDataGenerator
import pandas as pd

# datagen=ImageDataGenerator(rescale=1./255.,validation_split=0.25)

train_df = pd.read_csv('/content/fgnet_final_file.csv') # for fgnet "/content/fgnet_with_age_groups.csv" 
train_df['final_label'] = train_df['final_label'].astype(str)
# train_df['age_group'] = train_df['age_group'].astype(str)
# train_df['gender'] = train_df['gender'].astype(str)

# y_coll = ['age_group', 'gender']

train_datagen = ImageDataGenerator(
    rescale=1 / 255.0,
    validation_split=0.25
)

train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    directory="/content/cropped_fgnet/",
    x_col="full_path",
    y_col="final_label",
    target_size=(224, 224),
    batch_size=16,
    class_mode="categorical",  
    subset='training',
    shuffle=True,
    seed=42
)

valid_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    directory="/content/cropped_fgnet/",
    x_col="full_path",
    y_col="final_label",
    target_size=(224, 224),
    batch_size=16,
    class_mode="categorical",
    subset='validation',
    shuffle=True,
    seed=42
)
# Out:
# Found 711 validated image filenames belonging to 18 classes.
# Found 236 validated image filenames belonging to 18 classes.

# %%
from tensorflow.keras.callbacks import EarlyStopping

fgnet_model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy'],
)


es = EarlyStopping(monitor='val_accuracy', mode='max', patience=30,  restore_best_weights=True)

history  = k_means_wiki.fit(train_generator,
                    validation_data = valid_generator,
                    steps_per_epoch = train_generator.n//train_generator.batch_size,
                    validation_steps = valid_generator.n//valid_generator.batch_size,
                    epochs=100, callbacks=[es])
# Out:
# Epoch 1/100
# 44/44 [==============================] - 9s 152ms/step - loss: 3.6385 - accuracy: 0.0835 - val_loss: 2.6470 - val_accuracy: 0.0938
# Epoch 2/100
# 44/44 [==============================] - 6s 135ms/step - loss: 2.7305 - accuracy: 0.1252 - val_loss: 2.6630 - val_accuracy: 0.0625
# Epoch 3/100
# 44/44 [==============================] - 6s 144ms/step - loss: 2.5006 - accuracy: 0.1842 - val_loss: 2.7098 - val_accuracy: 0.1161
# Epoch 4/100
# 44/44 [==============================] - 6s 138ms/step - loss: 2.4461 - accuracy: 0.2058 - val_loss: 2.6276 - val_accuracy: 0.0804
# Epoch 5/100
# 44/44 [==============================] - 6s 133ms/step - loss: 2.4270 - accuracy: 0.2058 - val_loss: 2.7866 - val_accuracy: 0.0357
# Epoch 6/100
# 44/44 [==============================] - 6s 131ms/step - loss: 2.4206 - accuracy: 0.2058 - val_loss: 2.7927 - val_accuracy: 0.0670
# Epoch 7/100
# 44/44 [==============================] - 6s 130ms/step - loss: 2.4450 - accuracy: 0.2014 - val_loss: 2.8006 - val_accuracy: 0.0670
# Epoch 8/100
# 44/44 [==============================] - 6s 130ms/step - loss: 2.4025 - accuracy: 0.2072 - val_loss: 2.6571 - val_accuracy: 0.0804
# Epoch 9/100
# 44/44 [==============================] - 6s 130ms/step - loss: 2.3970 - accuracy: 0.2072 - val_loss: 2.8282 - val_accuracy: 0.0759
# Epoch 10/100
# 44/44 [==============================] - 6s 133ms/step - loss: 2.3750 - accuracy: 0.2144 - val_loss: 2.8148 - val_accuracy: 0.0446
# Epoch 11/100
# 44/44 [==============================] - 6s 132ms/step - loss: 2.3762 - accuracy: 0.2086 - val_loss: 2.6356 - val_accuracy: 0.1027
# Epoch 12/100
# 44/44 [==============================] - 6s 133ms/step - loss: 2.3619 - accuracy: 0.2115 - val_loss: 2.8113 - val_accuracy: 0.0357
# Epoch 13/100
# 44/44 [==============================] - 6s 135ms/step - loss: 2.3726 - accuracy: 0.2072 - val_loss: 2.7376 - val_accuracy: 0.0893
# Epoch 14/100
# 44/44 [==============================] - 6s 134ms/step - loss: 2.3612 - accuracy: 0.2101 - val_loss: 2.6051 - val_accuracy: 0.0759
# Epoch 15/100
# 44/44 [==============================] - 6s 135ms/step - loss: 2.3520 - accuracy: 0.2086 - val_loss: 2.5914 - val_accuracy: 0.0893
# Epoch 16/100
# 44/44 [==============================] - 6s 134ms/step - loss: 2.3182 - accuracy: 0.2129 - val_loss: 2.6159 - val_accuracy: 0.0625
# Epoch 17/100
# 44/44 [==============================] - 6s 132ms/step - loss: 2.3486 - accuracy: 0.2144 - val_loss: 2.5854 - val_accuracy: 0.1116
# Epoch 18/100
# 44/44 [==============================] - 6s 132ms/step - loss: 2.2859 - accuracy: 0.2129 - val_loss: 2.6848 - val_accuracy: 0.0804
# Epoch 19/100
# 44/44 [==============================] - 6s 131ms/step - loss: 2.2861 - accuracy: 0.2216 - val_loss: 2.6049 - val_accuracy: 0.0893
# Epoch 20/100
# 44/44 [==============================] - 6s 131ms/step - loss: 2.3240 - accuracy: 0.2187 - val_loss: 2.6249 - val_accuracy: 0.0804
# Epoch 21/100
# 44/44 [==============================] - 6s 131ms/step - loss: 2.3146 - accuracy: 0.2101 - val_loss: 2.5777 - val_accuracy: 0.0714
# Epoch 22/100
# 44/44 [==============================] - 6s 131ms/step - loss: 2.2575 - accuracy: 0.2288 - val_loss: 2.6045 - val_accuracy: 0.0938
# Epoch 23/100
# 44/44 [==============================] - 6s 133ms/step - loss: 2.2443 - accuracy: 0.2302 - val_loss: 2.5621 - val_accuracy: 0.0714
# Epoch 24/100
# 44/44 [==============================] - 6s 135ms/step - loss: 2.2406 - accuracy: 0.2302 - val_loss: 2.6225 - val_accuracy: 0.0938
# Epoch 25/100
# 44/44 [==============================] - 6s 136ms/step - loss: 2.2482 - accuracy: 0.2187 - val_loss: 2.5966 - val_accuracy: 0.0714
# Epoch 26/100
# 44/44 [==============================] - 6s 134ms/step - loss: 2.2841 - accuracy: 0.2245 - val_loss: 2.6453 - val_accuracy: 0.0982
# Epoch 27/100
# 44/44 [==============================] - 6s 133ms/step - loss: 2.3046 - accuracy: 0.2273 - val_loss: 2.6131 - val_accuracy: 0.0536
# Epoch 28/100
# 44/44 [==============================] - 6s 131ms/step - loss: 2.2359 - accuracy: 0.2360 - val_loss: 2.5716 - val_accuracy: 0.0893
# Epoch 29/100
# 44/44 [==============================] - 6s 137ms/step - loss: 2.2260 - accuracy: 0.2388 - val_loss: 2.5464 - val_accuracy: 0.1339
# Epoch 30/100
# 44/44 [==============================] - 6s 132ms/step - loss: 2.2576 - accuracy: 0.2345 - val_loss: 2.7997 - val_accuracy: 0.0893
# Epoch 31/100
# 44/44 [==============================] - 6s 131ms/step - loss: 2.2579 - accuracy: 0.2374 - val_loss: 2.6233 - val_accuracy: 0.0804
# Epoch 32/100
# 44/44 [==============================] - 6s 133ms/step - loss: 2.2042 - accuracy: 0.2532 - val_loss: 2.5421 - val_accuracy: 0.0893
# Epoch 33/100
# 44/44 [==============================] - 6s 134ms/step - loss: 2.2200 - accuracy: 0.2504 - val_loss: 2.6066 - val_accuracy: 0.0759
# Epoch 34/100
# 44/44 [==============================] - 6s 133ms/step - loss: 2.1834 - accuracy: 0.2388 - val_loss: 2.5819 - val_accuracy: 0.0848
# Epoch 35/100
# 44/44 [==============================] - 6s 132ms/step - loss: 2.2095 - accuracy: 0.2446 - val_loss: 2.5455 - val_accuracy: 0.1116
# Epoch 36/100
# 44/44 [==============================] - 6s 132ms/step - loss: 2.2069 - accuracy: 0.2432 - val_loss: 2.6662 - val_accuracy: 0.0938
# Epoch 37/100
# 44/44 [==============================] - 6s 131ms/step - loss: 2.2063 - accuracy: 0.2518 - val_loss: 2.5453 - val_accuracy: 0.0982
# Epoch 38/100
# 44/44 [==============================] - 6s 132ms/step - loss: 2.2142 - accuracy: 0.2345 - val_loss: 2.5939 - val_accuracy: 0.0938
# Epoch 39/100
# 44/44 [==============================] - 6s 132ms/step - loss: 2.2315 - accuracy: 0.2417 - val_loss: 2.6192 - val_accuracy: 0.1071
# Epoch 40/100
# 44/44 [==============================] - 6s 132ms/step - loss: 2.1831 - accuracy: 0.2374 - val_loss: 2.5064 - val_accuracy: 0.1250
# Epoch 41/100
# 44/44 [==============================] - 6s 132ms/step - loss: 2.1901 - accuracy: 0.2489 - val_loss: 2.6128 - val_accuracy: 0.1161
# Epoch 42/100
# 44/44 [==============================] - 6s 133ms/step - loss: 2.1734 - accuracy: 0.2532 - val_loss: 2.5296 - val_accuracy: 0.0804
# Epoch 43/100
# 44/44 [==============================] - 6s 133ms/step - loss: 2.2172 - accuracy: 0.2432 - val_loss: 2.5616 - val_accuracy: 0.1295
# Epoch 44/100
# 44/44 [==============================] - 6s 132ms/step - loss: 2.1903 - accuracy: 0.2547 - val_loss: 2.5323 - val_accuracy: 0.0938
# Epoch 45/100
# 44/44 [==============================] - 6s 132ms/step - loss: 2.1897 - accuracy: 0.2547 - val_loss: 2.5542 - val_accuracy: 0.1071
# Epoch 46/100
# 44/44 [==============================] - 6s 132ms/step - loss: 2.1362 - accuracy: 0.2662 - val_loss: 2.5572 - val_accuracy: 0.0982
# Epoch 47/100
# 44/44 [==============================] - 6s 131ms/step - loss: 2.1160 - accuracy: 0.2590 - val_loss: 2.5552 - val_accuracy: 0.1071
# Epoch 48/100
# 44/44 [==============================] - 6s 131ms/step - loss: 2.1268 - accuracy: 0.2532 - val_loss: 2.5749 - val_accuracy: 0.1027
# Epoch 49/100
# 44/44 [==============================] - 6s 131ms/step - loss: 2.1655 - accuracy: 0.2705 - val_loss: 2.7163 - val_accuracy: 0.0982
# Epoch 50/100
# 44/44 [==============================] - 6s 133ms/step - loss: 2.1131 - accuracy: 0.2705 - val_loss: 2.5932 - val_accuracy: 0.0759
# Epoch 51/100
# 44/44 [==============================] - 6s 134ms/step - loss: 2.1348 - accuracy: 0.2719 - val_loss: 2.5944 - val_accuracy: 0.0893
# Epoch 52/100
# 44/44 [==============================] - 6s 135ms/step - loss: 2.1322 - accuracy: 0.2604 - val_loss: 2.5802 - val_accuracy: 0.1116
# Epoch 53/100
# 44/44 [==============================] - 6s 134ms/step - loss: 2.0912 - accuracy: 0.2849 - val_loss: 2.5114 - val_accuracy: 0.1027
# Epoch 54/100
# 44/44 [==============================] - 6s 132ms/step - loss: 2.0970 - accuracy: 0.2619 - val_loss: 2.6630 - val_accuracy: 0.0938
# Epoch 55/100
# 44/44 [==============================] - 6s 131ms/step - loss: 2.1058 - accuracy: 0.2763 - val_loss: 2.6354 - val_accuracy: 0.1027
# Epoch 56/100
# 44/44 [==============================] - 6s 131ms/step - loss: 2.1178 - accuracy: 0.2547 - val_loss: 2.5389 - val_accuracy: 0.1250
# Epoch 57/100
# 44/44 [==============================] - 6s 140ms/step - loss: 2.0480 - accuracy: 0.2748 - val_loss: 2.4984 - val_accuracy: 0.1518
# Epoch 58/100
# 44/44 [==============================] - 6s 134ms/step - loss: 2.1875 - accuracy: 0.2489 - val_loss: 2.6278 - val_accuracy: 0.1384
# Epoch 59/100
# 44/44 [==============================] - 6s 133ms/step - loss: 2.1696 - accuracy: 0.2532 - val_loss: 2.6961 - val_accuracy: 0.1027
# Epoch 60/100
# 44/44 [==============================] - 6s 132ms/step - loss: 2.1537 - accuracy: 0.2763 - val_loss: 2.8597 - val_accuracy: 0.0938
# Epoch 61/100
# 44/44 [==============================] - 6s 131ms/step - loss: 2.1142 - accuracy: 0.2633 - val_loss: 2.6554 - val_accuracy: 0.0848
# Epoch 62/100
# 44/44 [==============================] - 6s 132ms/step - loss: 2.1430 - accuracy: 0.2619 - val_loss: 2.6205 - val_accuracy: 0.0938
# Epoch 63/100
# 44/44 [==============================] - 6s 132ms/step - loss: 2.1101 - accuracy: 0.2878 - val_loss: 2.6452 - val_accuracy: 0.1027
# Epoch 64/100
# 44/44 [==============================] - 6s 133ms/step - loss: 2.0748 - accuracy: 0.2691 - val_loss: 2.6137 - val_accuracy: 0.0804
# Epoch 65/100
# 44/44 [==============================] - 6s 133ms/step - loss: 2.0575 - accuracy: 0.2835 - val_loss: 2.6087 - val_accuracy: 0.1116
# Epoch 66/100
# 44/44 [==============================] - 6s 132ms/step - loss: 2.0760 - accuracy: 0.2662 - val_loss: 2.6871 - val_accuracy: 0.0759
# Epoch 67/100
# 44/44 [==============================] - 6s 132ms/step - loss: 2.0670 - accuracy: 0.2705 - val_loss: 2.9469 - val_accuracy: 0.1250
# Epoch 68/100
# 44/44 [==============================] - 6s 132ms/step - loss: 2.1110 - accuracy: 0.2777 - val_loss: 2.6366 - val_accuracy: 0.1161
# Epoch 69/100
# 44/44 [==============================] - 6s 139ms/step - loss: 2.1160 - accuracy: 0.2719 - val_loss: 2.5925 - val_accuracy: 0.1741
# Epoch 70/100
# 44/44 [==============================] - 6s 131ms/step - loss: 2.0563 - accuracy: 0.2921 - val_loss: 2.6001 - val_accuracy: 0.1295
# Epoch 71/100
# 44/44 [==============================] - 6s 131ms/step - loss: 2.1017 - accuracy: 0.3108 - val_loss: 2.6558 - val_accuracy: 0.1071
# Epoch 72/100
# 44/44 [==============================] - 6s 131ms/step - loss: 2.0685 - accuracy: 0.2748 - val_loss: 2.6465 - val_accuracy: 0.1429
# Epoch 73/100
# 44/44 [==============================] - 6s 133ms/step - loss: 2.0454 - accuracy: 0.2921 - val_loss: 2.6449 - val_accuracy: 0.1116
# Epoch 74/100
# 44/44 [==============================] - 6s 135ms/step - loss: 2.0477 - accuracy: 0.2950 - val_loss: 2.6647 - val_accuracy: 0.1250
# Epoch 75/100
# 44/44 [==============================] - 6s 136ms/step - loss: 2.0834 - accuracy: 0.2878 - val_loss: 2.6676 - val_accuracy: 0.1295
# Epoch 76/100
# 44/44 [==============================] - 6s 133ms/step - loss: 2.0542 - accuracy: 0.3007 - val_loss: 2.6586 - val_accuracy: 0.1116
# Epoch 77/100
# 44/44 [==============================] - 6s 132ms/step - loss: 2.0250 - accuracy: 0.3209 - val_loss: 2.7714 - val_accuracy: 0.1339
# Epoch 78/100
# 44/44 [==============================] - 6s 133ms/step - loss: 2.0699 - accuracy: 0.2964 - val_loss: 2.7437 - val_accuracy: 0.0938
# Epoch 79/100
# 44/44 [==============================] - 6s 132ms/step - loss: 2.0471 - accuracy: 0.3065 - val_loss: 2.7027 - val_accuracy: 0.0982
# Epoch 80/100
# 44/44 [==============================] - 6s 132ms/step - loss: 2.0134 - accuracy: 0.3137 - val_loss: 2.7403 - val_accuracy: 0.0982
# Epoch 81/100
# 44/44 [==============================] - 6s 134ms/step - loss: 2.0281 - accuracy: 0.3022 - val_loss: 2.7294 - val_accuracy: 0.0848
# Epoch 82/100
# 44/44 [==============================] - 6s 132ms/step - loss: 2.0070 - accuracy: 0.3165 - val_loss: 2.6682 - val_accuracy: 0.1429
# Epoch 83/100
# 44/44 [==============================] - 6s 133ms/step - loss: 2.0491 - accuracy: 0.2906 - val_loss: 2.8214 - val_accuracy: 0.1027
# Epoch 84/100
# 44/44 [==============================] - 6s 133ms/step - loss: 2.0210 - accuracy: 0.2993 - val_loss: 2.7384 - val_accuracy: 0.1027
# Epoch 85/100
# 44/44 [==============================] - 6s 131ms/step - loss: 2.0377 - accuracy: 0.3007 - val_loss: 2.7710 - val_accuracy: 0.0759
# Epoch 86/100
# 44/44 [==============================] - 6s 132ms/step - loss: 2.0544 - accuracy: 0.3022 - val_loss: 2.7635 - val_accuracy: 0.1027
# Epoch 87/100
# 44/44 [==============================] - 6s 133ms/step - loss: 1.9945 - accuracy: 0.2935 - val_loss: 2.7708 - val_accuracy: 0.0848
# Epoch 88/100
# 44/44 [==============================] - 6s 133ms/step - loss: 1.9790 - accuracy: 0.3165 - val_loss: 2.8342 - val_accuracy: 0.1161
# Epoch 89/100
# 44/44 [==============================] - 6s 133ms/step - loss: 1.9794 - accuracy: 0.3281 - val_loss: 2.7779 - val_accuracy: 0.1071
# Epoch 90/100
# 44/44 [==============================] - 6s 130ms/step - loss: 1.9892 - accuracy: 0.3266 - val_loss: 2.8637 - val_accuracy: 0.1071
# Epoch 91/100
# 44/44 [==============================] - 6s 132ms/step - loss: 1.9999 - accuracy: 0.3252 - val_loss: 2.8696 - val_accuracy: 0.1071
# Epoch 92/100
# 44/44 [==============================] - 6s 133ms/step - loss: 1.9571 - accuracy: 0.3424 - val_loss: 2.8291 - val_accuracy: 0.1071
# Epoch 93/100
# 44/44 [==============================] - 6s 134ms/step - loss: 1.9879 - accuracy: 0.2964 - val_loss: 2.9408 - val_accuracy: 0.1205
# Epoch 94/100
# 44/44 [==============================] - 6s 133ms/step - loss: 1.9531 - accuracy: 0.3108 - val_loss: 2.9279 - val_accuracy: 0.1071
# Epoch 95/100
# 44/44 [==============================] - 6s 133ms/step - loss: 1.9625 - accuracy: 0.3424 - val_loss: 2.8489 - val_accuracy: 0.0848
# Epoch 96/100
# 44/44 [==============================] - 6s 133ms/step - loss: 1.9469 - accuracy: 0.3165 - val_loss: 2.8310 - val_accuracy: 0.0759
# Epoch 97/100
# 44/44 [==============================] - 6s 133ms/step - loss: 2.0009 - accuracy: 0.3324 - val_loss: 2.9561 - val_accuracy: 0.1295
# Epoch 98/100
# 44/44 [==============================] - 6s 134ms/step - loss: 1.9252 - accuracy: 0.3324 - val_loss: 2.9174 - val_accuracy: 0.1071
# Epoch 99/100
# 44/44 [==============================] - 6s 136ms/step - loss: 1.9670 - accuracy: 0.3324 - val_loss: 3.2608 - val_accuracy: 0.1250

# %%
import matplotlib.pyplot as plt
# training loss and validation loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['loss', 'val_loss'], loc='upper left')
plt.show()

# %%
# training accuracy and validation accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['accuracy', 'val_accuracy'], loc='upper left')
plt.show()
